# %%
import mysql.connector
# if mysql.connector is not present then use pip install mysql.connector

# %%
# importing all libraries
from tkinter import *
import tkinter as ttk
from tkinter.ttk import Combobox
import random
import datetime
import time
from tkinter import messagebox
import mysql.connector

# %%
class Hospital:
    def __init__(self,root):
        self.root=root
        self.root.title("Hospital Management System")
        self.root.geometry("1540x800+0+0")
        
        # creating a varaible for all our entries
        
        self.NameofTablets=StringVar()
        self.ReferenceNo=StringVar()
        self.DoseNo=StringVar()
        self.NoOfTablets=StringVar()
        self.IssueDate=StringVar()
        self.ExpiryDate=StringVar()
        self.DailyDose=StringVar()
        self.SideEffect=StringVar()
        self.IssueDate=StringVar()
        self.BloodPressure=StringVar()
        self.StorageAdvice=StringVar()
        self.Medication=StringVar()
        self.PatientID=StringVar()
        self.NHSNumber=StringVar()
        self.PatientName=StringVar()
        self.PatientAddress=StringVar()
        self.FurthurInform=StringVar()
        
        lbltitle=Label(self.root,bd=20,relief=RIDGE,text="Hospital Management System",fg="red",
                      bg="white",font=("times new roman",50,"bold"))
        lbltitle.pack(side=TOP,fill="x")
        # creating a data frame
        Dataframe=Frame(self.root,bd=20,relief=RIDGE)
        Dataframe.place(x=0,y=130,width=1520,height=350)
        
        # creating the left dataframe
        DataframeLeft=LabelFrame(Dataframe,bd=10,padx=10,relief=RIDGE,font=("arial",12,"bold"),text="Patient Information")
        DataframeLeft.place(x=0,y=5,width=800,height=300)
        
        # creating the right data frame
        
        Dataframeright=LabelFrame(Dataframe,bd=10,padx=20,relief=RIDGE,font=("arial",12,"bold"),text="Description")
        Dataframeright.place(x=810,y=5,width=450,height=300)
        
        # creating a button frame
        buttonframe=Frame(self.root,bd=10,relief=RIDGE)
        buttonframe.place(x=0,y=500,width=1285,height=70)
        
        # creating a details frame
        detailsframe=Frame(self.root,bd=10,relief=RIDGE)
        detailsframe.place(x=0,y=580,width=1285,height=125)
        
        
        # insering labels in the left dataframe
        
        labelnametablet=Label(DataframeLeft,text="NameOfTablet",font=("times new roman",11,"bold"),padx=2,pady=6)
        labelnametablet.grid(row=0,column=0)
        
        # inserting a combo vox
        comNameTablet=Combobox(DataframeLeft,font=("times new roman",11,"bold"),textvariable=self.NameofTablets, width=33,values=("Nice","Corona Vaccine","Acetaminpphen","Addredall","amlodipine","Ativan"))
        #comNameTablet["Values"]=("Nice","Corona Vaccine","Acetaminpphen","Addredall","amlodipine","Ativan")
        comNameTablet.grid(row=0,column=1)
        
        lableref=Label(DataframeLeft,text="ReferenceNo",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=1,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),width=22)
        textref.grid(row=1,column=1)
        
        # for dose No.
        lableref=Label(DataframeLeft,text="DoseNo",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=2,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.DoseNo, width=22)
        textref.grid(row=2,column=1)
        
        # for No of Tablets
        lableref=Label(DataframeLeft,text="NoOfTablets",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=3,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.NoOfTablets,width=22)
        textref.grid(row=3,column=1)
        
        # for issue date
        lableref=Label(DataframeLeft,text="IssueDate",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=4,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.IssueDate ,width=22)
        textref.grid(row=4,column=1)
        
        
        # for expiry date
        lableref=Label(DataframeLeft,text="ExpiryDate",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=5,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.ExpiryDate, width=22)
        textref.grid(row=5,column=1)
        
        
        
        
        # for daily dose
        lableref=Label(DataframeLeft,text="Daily Dose",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=6,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.DailyDose, width=22)
        textref.grid(row=6,column=1)
        
        
        # for Side effect
        lableref=Label(DataframeLeft,text="SideEffect",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=7,column=0,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.SideEffect,width=22)
        textref.grid(row=7,column=1)
        
        # for furthur infromation
        lableref=Label(DataframeLeft,text="FurthurInform",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=0,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.FurthurInform, width=22)
        textref.grid(row=0,column=3)
        
        
        # for Blood Pressure
        lableref=Label(DataframeLeft,text="BloodPressure",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=1,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.BloodPressure, width=22)
        textref.grid(row=1,column=3)
        
        
        
        # for Storage Advice
        lableref=Label(DataframeLeft,text="StorageAdvice",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=2,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.StorageAdvice, width=22)
        textref.grid(row=2,column=3)
        
        
        # for Medication
        lableref=Label(DataframeLeft,text="Medication",font=("times new roman",10,"bold"),padx=2)
        lableref.grid(row=3,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.Medication ,width=22)
        textref.grid(row=3,column=3)
        
        # for Patient ID
        lableref=Label(DataframeLeft,text="PatientID",font=("times new roman",10,"bold"),padx=2)
        lableref.grid(row=4,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.PatientID, width=22)
        textref.grid(row=4,column=3)
        
        
        #For NHS Number
        lableref=Label(DataframeLeft,text="NHSNumber",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=5,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.NHSNumber, width=22)
        textref.grid(row=5,column=3)
        
        
        # for patient Name
        lableref=Label(DataframeLeft,text="PatientName",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=6,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.PatientName, width=22)
        textref.grid(row=6,column=3)
        
        
        # for patient Address
        lableref=Label(DataframeLeft,text="PatientAddress",font=("times new roman",11,"bold"),padx=2)
        lableref.grid(row=7,column=2,sticky=W)
        textref=Entry(DataframeLeft,font=("times new roman",13,"bold"),textvariable=self.PatientAddress, width=22)
        textref.grid(row=7,column=3)
        
        # dataframe right and add presecription in the right dataframe
        
        self.txtPrescription=Text(Dataframeright,font=("times new roman",13,"bold"),width=35,height=14)
        self.txtPrescription.grid(row=0,column=0)
        
        # creating buttons
        
        btnPrescription=Button(buttonframe,command=self.iprescriptionm, text="Prescription",bg="green",fg="white",font=("times new roman",13,"bold"),width=16,height=2)
        btnPrescription.grid(row=0,column=0)
        
        # for prescription data
        btnPrescriptiondata=Button(buttonframe,text="Prescription Data",bg="green",fg="white",font=("times new roman",13,"bold"),width=16,height=2)
        btnPrescriptiondata.grid(row=0,column=1)
        
        # for Update Data
        btnPrescription=Button(buttonframe,command=self.update,text="Update Data",bg="green",fg="white",font=("times new roman",13,"bold"),width=16,height=2)
        btnPrescription.grid(row=0,column=2)
        
        # for deleting data
        btndelete=Button(buttonframe,command=self.idelete, text="delete",bg="green",fg="white",font=("times new roman",13,"bold"),width=16,height=2)
        btndelete.grid(row=0,column=3)
        
        # for clear the screen
        btnclear=Button(buttonframe,text="ClearScreen",command=self.clear, bg="green",fg="white",font=("times new roman",13,"bold"),width=16,height=2)
        btnclear.grid(row=0,column=4)
        
        # for exitting 
        
        btnexit=Button(buttonframe,command=self.iexit, text="Exit",bg="green",fg="white",font=("times new roman",13,"bold"),width=16,height=2)
        btnexit.grid(row=0,column=5)
        
        
        
        # for scroll bar
        
        x_scroll=Scrollbar(detailsframe,orient=HORIZONTAL)
        y_scroll=Scrollbar(detailsframe,orient=VERTICAL)
        
        x_scroll.pack(side=BOTTOM,fill=X)
        y_scroll.pack(side=RIGHT,fill=Y)
        
        
        self.Hospitaltable=Treeview(detailsframe,column=("NameOfTablet","RefernceNo","DoseNo.","NoofTablets","IssueDate","ExpiryDate","DailyDose",
                                                          "SideEffect","BloodPressure","StotrageAdvice","Medication",
                                                          "NHSNumber","PatientName","PatientAddress"),xscrollcommand=x_scroll.set,yscrollcommand=y_scroll.set,show='headings')
       
        
        # command to show in xview and yview
        x_scroll=Scrollbar(command=self.Hospitaltable.xview)
        y_scroll=Scrollbar(command=self.Hospitaltable.yview)
        
        # to give heading to the table
        # self.Hospitaltable.heading("TabletName",text="Name of Tablet")
        
        self.Hospitaltable.pack(fill=BOTH,expand=1)
        self.hospital_table.bind("<ButtonRelease-1>",self.get_cursor())
        self.hospital_table.bind("")
        self.fetch_data()
    # to get the prescription of the data
    def isprescriptiondata(self):
        
        if (self.NameofTablets.get()=="" or self.ReferenceNo.get()==""):
            messagebox.showerror("Error All Fields are required")
        else:
            connect=mysql.connector.connect(host="localhost",username="root",password="aryan0035",database="sys")
            mycursor=conn.cursor()
            mycursor.execute("insert into Hospital values NamofTablets=%s,Refernce No=%s,NoOfTablets=%s,IssueDate=%s,ExpirtDate=%s,SideEffect=%s,BloodPressure=%s,StorageAdvice=%s,Medication=%s,PatientID=%s,NHSNumber=%s,PateintName=%s,PatientAddress=%s,FurthurInform=%s)"
                                                                                ,(self.NameofTablets.get(),
                                                                               self.ReferenceNo.get(),
                                                                               self.DoseNo.get(),
                                                                                self.NoOfTablets.get(),
                                                                                self.IssueDate(),
                                                                                self.ExpiryDate.get(),
                                                                                self.DailyDose.get(),
                                                                                self.SideEffect.get(),
                                                                                self.BloodPressure.get(),
                                                                                self.StorageAdvice.get(),
                                                                                self.Medication.get(),
                                                                                self.PatientID.get(),
                                                                                self.NHSNumber.get(),
                                                                                self.PatientName.get(),
                                                                                self.PatientAddress.get(),
                                                                                self.FurthurInform().get())
            conn.commit()
            self.fetch_data()
            conn.close()
            messagebox.showinfo("Record has been added ! Successfully")
                             
    # to update the records of the management system
    def update(self):
        conn=mysql.connector.connect(host="localhost",username="root",password="9760",database="mydata")
        mycursor=conn.connect()
        mycursor.execute("update hospital set NamofTablets=%s,NoOfTablets=%s,IssueDate=%s,ExpirtDate=%s,SideEffect=%s,BloodPressure=%s,StorageAdvice=%s,Medication=%s,PatientID=%s,NHSNumber=%s,PateintName=%s,PatientAddress=%s,FurthurInform=%s where Refernce No=%s)"
                                                                                ,(self.NameofTablets.get(),
                                                                                  self.DoseNo.get(),
                                                                                self.NoOfTablets.get(),
                                                                                self.IssueDate(),
                                                                                self.ExpiryDate.get(),
                                                                                self.DailyDose.get(),
                                                                                self.SideEffect.get(),
                                                                                self.BloodPressure.get(),
                                                                                self.StorageAdvice.get(),
                                                                                self.Medication.get(),
                                                                                self.PatientID.get(),
                                                                                self.NHSNumber.get(),
                                                                                self.PatientName.get(),
                                                                                self.PatientAddress.get(),
                                                                                self.FurthurInform().get()
                                                                                 self.ReferenceNo.get())
            conn.commit()
            conn.close()
            messagebox.showinfo("Records are updated")
                             
     # check the data as when we click on the data it shows it is inserted but is not shown in the data to fetch 
    def fetch_data(self):
        conn=mysql.connector.connect(host="localhost",username="root",password="9760",database="mydata")
        mycursor=conn.connect()
        mycursor.execute("select * from hospital")
        rows=mycursor.fetchall()
        if len(rows)!=0:
            self.hospital_table.delete(*self.hospital_table.get_children())
            for i in rows:
                self.hospital_table.insert("",END,values=i)
                conn.commit()
                conn.close()
                             
    # to input all the fields which are selected by cursor on the top window frame                        
    def get_cursor(self,event=""):
        cursor_row=self.hospital_table.focus()
        contents=self.hospital_table.item(cursor_row)
        rows=cursor['values']
        self.NameofTablets.set(rows[0])
        self.ReferenceNo.set(rows[1])
        self.DoseNo.set(rows[2])
        self.NoOfTablets.set(rows[3])
        self.IssueDate.set(rows[4])
        self.ExpiryDate.set(rows[5])
        self.DailyDose.set(rows[6])
        self.SideEffect.set(rows[7])
        self.IssueDate.set(rows[8])
        self.BloodPressure.set(rows[9])
        self.StorageAdvice.set(rows[10])
        self.Medication.set(rows[11])
        self.PatientID.set(rows[12])
        self.NHSNumber.set(rows[13])
        self.PatientName.set(rows[14])
        self.PatientAddress.set(rows[15])
        self.FurthurInform.set(rows[16]) 
    # To get the prescription data
                            
    def iprescription(self):
        self.hospital_table.insert(END,"NameofTablet:\t\t\t "+ self.NameofTablets.get()+"\n")
        self.hospital_table.insert(END,"ReferenceNo:"+self.ReferenceNo.get()+ "/n")
        self.hospital_table.insert(END,"DoseNo: "+self.DoseNo.get()+ "/n")
        self.hospital_table.insert(END,"NoofTablets:\t\t\t "+self.NoofTablets.get()+"\n")
        self.hospital_table.insert(END,"IssueDate:\t\t\t "+self.IssueDate.get()+ "/n")
        self.hospital_table.insert(END,"Expiry Date:\t\t\t "+self.ExpiryDate.get()+ "/n")
        self.hospital_table.insert(END,"Daily Dose: "+self.DailyDose.get()+"/n")
        self.hospital_table.insert(END,"Side Effect:\t "+self.SideEffect.get()+"/n")
        self.hospital_table.insert(END,"Issue Date:\t\t "+self.IssueDate.get()+"/n")
        self.hospital_table.insert(END,"Blood Pressure:\t\t "+self.BloodPressure.get()+"/n")
        self.hospital_table.insert(END,"Storage Advice: \t\t "+self.StorageAdvice.get()+"/n")
        self.hospital_table.insert(END,"Medication: \t\t "+self.Medication.get()+"/n")
        self.hospital_table.insert(END,"Patient ID:\t\t ",self.PatientID.get()+"/n")
        self.hospital_table.insert(END,"NHS Number: \t\t ",self.NHSNumber.get()+"/n")
        self.hospital_table.insert(END,"Patient Name:\t\t ",self.PatientName.get()+"/n")
        self.hospital_table.insert(END,"Patien Address: \t\t", self.PatientAddress.get()+"/n")
        self.hospital_table.insert(END,"Furthur Infromation: ",self.FurthurInform.get()+"/n")
                         
    def idelete(self):
        conn=mysql.connector.connect(host="localhost",username="root",password="9760",database="mydata")
        mycursor=conn.connect()
        query="delete from hospital where refernce no=%s"
        value=self.ReferenceNo.get()
        mycursor.execute(query,value)
        conn.commit()
        conn.close()
        self.fetch_data()
        messagebox.showinfo("Patient has been deleted successfully")
                         
    # to clear the screen and set all records as blanks                     
    def clear(self):
        self.NameofTablets.set("")
        self.ReferenceNo.set("")
        self.DoseNo.set("")
        self.NoOfTablets.set("")
        self.IssueDate.set("")
        self.ExpiryDate.set("")
        self.DailyDose.set("")
        self.SideEffect.set("")
        self.IssueDate.set("")
        self.BloodPressure.set("")
        self.StorageAdvice.set("")
        self.Medication.set("")
        self.PatientID.set("")
        self.NHSNumber.set("")
        self.PatientName.set("")
        self.PatientAddress.set("")
        self.FurthurInform.set("")   
        self.txtPrescription.delete("1.0",END)
                         
    # function to exit the Hospital Management System
                         
    def iexit(self):
        Iexit=messagebox.askyesno("Hospital Management System ! \n Sure you want to exit")
        if Iexit>1:
                root.destroy()
                return
# Out:
#   Input In [19]
#     conn.commit()
#     ^
# SyntaxError: invalid syntax

# %%
root=Tk()
ob=Hospital(root)
root.mainloop()

# %%
print("Aryan")
# Out:
# Aryan
